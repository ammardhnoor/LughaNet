# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 564.5 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 455.2 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 230.0 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 785.0/785.0 kB 221.3 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 125.0 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 170.0 kB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Could not fetch URL https://pypi.ngc.nvidia.com/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.ngc.nvidia.com', port=443): Max retries exceeded with url: /pip/ (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)'))) - skipping
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load the tokenizer and model
model_name = "facebook/nllb-200-distilled-600M"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Function to translate text
def translate_text(input_text, src_lang, tgt_lang):
    tokenizer.src_lang = src_lang
    encoded_input = tokenizer(input_text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_input, forced_bos_token_id=tokenizer.lang_code_to_id[tgt_lang])
    translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    return translated_text

# Load JSON file and print the first 10 positions
json_file_path = 'part1.json'  # Replace with your JSON file path
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Print the first 10 positions
for i, item in enumerate(data[:10]):
    print(f"{i+1}: {item}")

    # Translate the text
    translated = translate_text(item, "eng_Latn", "arb_Arab")
    print(f"Translated: {translated}")
# Out:
# /opt/conda/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# ...

# %%
# Load JSON file and print the first 10 positions
json_file_path = 'part1.json'  # Replace with your JSON file path
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Print the first 10 positions
for i, item in enumerate(data[:20]):
    print(f"{i+1}: {item}")

    # Translate the text
    translated = translate_text(item, "eng_Latn", "arb_Arab")
    print(f"Translated: {translated}")
# Out:
# 1: rocket larkspur
# Translated: صاروخ لراكسبور
# 2: pea jacket
# Translated: سترة البازلاء
# 3: genus actinomyces
# Translated: جنس "آكتينوميس"
# 4: aerobacter aerogenes
# Translated: طائرات الطائرات
# 5: at the ready
# Translated: في المستقبل
# 6: genus pecopteris
# Translated: جنس بيكوبتريس
# 7: blacktail jackrabbit
# Translated: أرنب ذيل أسود
# 8: press lord
# Translated: " صحيفة "
# 9: penicillin v potassium
# Translated: البنسلين مقابل البوتاسيوم
# 10: reduced instruction set computing
# Translated: الحوسبة المحدودة لمجموعة التعليمات
# 11: discina macrospora
# Translated: "المركز"
# 12: frankfurter bun
# Translated: خُبز فرنكفورت
# 13: chinese pea tree
# Translated: شجرة البازلاء الصينية
# 14: raisin cookie
# Translated: كعك العنب
# 15: ignoratio elenchi
# Translated: الجهل
# 16: two dimensionality
# Translated: الابعادين
# 17: genus artemisia
# Translated: جنس artemisia
# 18: mausoleum at halicarnasus
# Translated: المزار في هالكارناسوس
# 19: raw umber
# Translated: الخام
# ...

# %%
# Load JSON file and print the first 10 positions
json_file_path = 'part1.json'  # Replace with your JSON file path
output_file_path = 'translated_output11.json'  # Replace with desired output file path

# %%
# Load JSON file and print the first 10 positions
json_file_path = 'part1.json'  # Replace with your JSON file path
output_file_path = 'translated_output.json'  # Replace with desired output file path

with open(json_file_path, 'r') as file:
    data = json.load(file)

# Translate and save the first 10 positions
translated_data = []
for i, item in enumerate(data[:2407]):
    print(f"{i+1}: {item}")
    translated = translate_text(item, "eng_Latn", "arb_Arab")
    print(f"Translated: {translated}")
    translated_data.append({"English": item, "Arabic": translated})

# Save translated data to a new JSON file
with open(output_file_path, 'w') as outfile:
    json.dump(translated_data, outfile, ensure_ascii=False, indent=4)

print(f"Translated data saved to {output_file_path}")
# Out:
# 1: rocket larkspur
# Translated: صاروخ لراكسبور
# 2: pea jacket
# Translated: سترة البازلاء
# 3: genus actinomyces
# Translated: جنس "آكتينوميس"
# 4: aerobacter aerogenes
# Translated: طائرات الطائرات
# 5: at the ready
# Translated: في المستقبل
# 6: genus pecopteris
# Translated: جنس بيكوبتريس
# 7: blacktail jackrabbit
# Translated: أرنب ذيل أسود
# 8: press lord
# Translated: " صحيفة "
# 9: penicillin v potassium
# Translated: البنسلين مقابل البوتاسيوم
# 10: reduced instruction set computing
# Translated: الحوسبة المحدودة لمجموعة التعليمات
# 11: discina macrospora
# Translated: "المركز"
# 12: frankfurter bun
# Translated: خُبز فرنكفورت
# 13: chinese pea tree
# Translated: شجرة البازلاء الصينية
# 14: raisin cookie
# Translated: كعك العنب
# 15: ignoratio elenchi
# Translated: الجهل
# 16: two dimensionality
# Translated: الابعادين
# 17: genus artemisia
# Translated: جنس artemisia
# 18: mausoleum at halicarnasus
# Translated: المزار في هالكارناسوس
# 19: raw umber
# Translated: الخام
# ...
